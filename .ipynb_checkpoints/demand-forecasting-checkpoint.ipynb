# %%
# Importing dependencies
import sklearn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch
import captum # for explanation methods (IG & LRP)
import statsmodels # for baseline comparison
import arch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       5 import numpy as np
#       6 import torch
# ----> 7 import captum # for explanation methods (IG & LRP)
#       8 import statsmodels # for baseline comparison
#       9 import arch
#
# ModuleNotFoundError: No module named 'captum'

# %%
# Loading the data
data = pd.read_csv("Supply Chain Demand Forecasting Dataset.csv")
print(data.isnull().sum())
# Out:
# date                      0
# product_id                0
# sales_units               0
# holiday_season            0
# promotion_applied         0
# competitor_price_index    0
# economic_index            0
# weather_impact            0
# price                     0
# discount_percentage       0
# sales_revenue             0
# region_Europe             0
# region_North America      0
# store_type_Retail         0
# store_type_Wholesale      0
# category_Cabinets         0
# category_Chairs           0
# category_Sofas            0
# category_Tables           0
# future_demand             0
# dtype: int64

# %%
# EDA analysis

# %%
# Preprocessing + train/test sp][lit

# %%
# LSTM training and evaluation

# %%
# (Maybe ARIMA/GARCH training and evaluation)

# %%
# (Maybe Comparison between the models)

# %%
# Integrated Gradients
#Sundararajan et al., 2017
# Ismail et al., 2020

# %%
# LRP
# Bach et al., 2015
# Ismail et al., 2020

# %%
# (Maybe SHAP explanation to compare)

# %%
# Comparison of explanation methods
# Ismail et al., 2020

# %%
# Conclusion
